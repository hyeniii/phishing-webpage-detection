# %% [markdown]
# ## Webpage Phishing Detection EDA - Riu
# ### *Columns 46 - 67*

# %%
#Import Modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Read data
df = pd.read_csv("../data/dataset_phishing.csv")

# %%
#Subset data (columns 46 - 67 and label)
df = df.iloc[:, np.r_[45:67, 88]]

# %%
#Display sample
pd.set_option('display.max_columns', None)
df.sample(10, random_state = 373)
# Out:
#        longest_words_raw  longest_word_host  longest_word_path  avg_words_raw  \
# 6309                  17                 14                 17       7.538462
# 3116                  13                 13                  9       8.333333
# 8307                  10                  9                 10       6.833333
# 8309                   9                  9                  8       6.200000
# 2807                  40                 10                 40       9.894737
# 7693                  12                 12                  9       7.000000
# 1090                   9                  9                  8       5.800000
# 9597                  13                 13                  8       4.533333
# 9546                  12                 12                 10       6.666667
# 11195                 10                 10                  0       6.500000
#
#        avg_word_host  avg_word_path  phish_hints  domain_in_brand  \
# ...

# %%
#Display shape
df.shape
# Out:
# (11430, 23)

# %%
#Column data types
df.dtypes
# Out:
# longest_words_raw         int64
# longest_word_host         int64
# longest_word_path         int64
# avg_words_raw           float64
# avg_word_host           float64
# avg_word_path           float64
# phish_hints               int64
# domain_in_brand           int64
# brand_in_subdomain        int64
# brand_in_path             int64
# suspecious_tld            int64
# statistical_report        int64
# nb_hyperlinks             int64
# ratio_intHyperlinks     float64
# ratio_extHyperlinks     float64
# ratio_nullHyperlinks      int64
# nb_extCSS                 int64
# ratio_intRedirection      int64
# ratio_extRedirection    float64
# ratio_intErrors           int64
# ratio_extErrors         float64
# login_form                int64
# status                   object
# dtype: object

# %%
#Check for potentially missing values
df.isna().sum()
# Out:
# longest_words_raw       0
# longest_word_host       0
# longest_word_path       0
# avg_words_raw           0
# avg_word_host           0
# avg_word_path           0
# phish_hints             0
# domain_in_brand         0
# brand_in_subdomain      0
# brand_in_path           0
# suspecious_tld          0
# statistical_report      0
# nb_hyperlinks           0
# ratio_intHyperlinks     0
# ratio_extHyperlinks     0
# ratio_nullHyperlinks    0
# nb_extCSS               0
# ratio_intRedirection    0
# ratio_extRedirection    0
# ratio_intErrors         0
# ratio_extErrors         0
# login_form              0
# status                  0
# dtype: int64

# %% [markdown]
# ### *Distribution of Each Feature*

# %%
#Plot features 46 - 51
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize = (17, 10))
sns.histplot(data = df, x = df.columns[0], ax = axs[0, 0], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[1], ax = axs[0, 1], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[2], ax = axs[0, 2], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[3], ax = axs[1, 0], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[4], ax = axs[1, 1], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[5], ax = axs[1, 2], color = "salmon", bins = 100)
plt.show()

# %%
#Plot features 52 - 57
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize = (17, 10))
sns.countplot(data = df, x = df.columns[6], ax = axs[0, 0], color = "salmon")
sns.countplot(data = df, x = df.columns[7], ax = axs[0, 1], color = "salmon", width = 0.25)
sns.countplot(data = df, x = df.columns[8], ax = axs[0, 2], color = "salmon", width = 0.25)
sns.countplot(data = df, x = df.columns[9], ax = axs[1, 0], color = "salmon", width = 0.25)
sns.countplot(data = df, x = df.columns[10], ax = axs[1, 1], color = "salmon", width = 0.25)
sns.countplot(data = df, x = df.columns[11], ax = axs[1, 2], color = "salmon", width = 0.4)
plt.show()

# %%
#Plot features 58 - 63
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize = (17, 10))
sns.histplot(data = df, x = df.columns[12], ax = axs[0, 0], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[13], ax = axs[0, 1], color = "salmon", bins = 100)
sns.histplot(data = df, x = df.columns[14], ax = axs[0, 2], color = "salmon", bins = 100)
sns.countplot(data = df, x = df.columns[15], ax = axs[1, 0], color = "salmon", width = 0.1)
sns.histplot(data = df, x = df.columns[16], ax = axs[1, 1], color = "salmon", bins = 100)
sns.countplot(data = df, x = df.columns[17], ax = axs[1, 2], color = "salmon", width = 0.1)
plt.show()

# %%
#Plot features 64 - 67
fig, axs = plt.subplots(ncols = 2, nrows = 2, figsize = (17, 10))
sns.histplot(data = df, x = df.columns[18], ax = axs[0, 0], color = "salmon", bins = 100)
sns.countplot(data = df, x = df.columns[19], ax = axs[0, 1], color = "salmon", width = 0.1)
sns.histplot(data = df, x = df.columns[20], ax = axs[1, 0], color = "salmon", bins = 100)
sns.countplot(data = df, x = df.columns[21], ax = axs[1, 1], color = "salmon", width = 0.25)
plt.show()

# %% [markdown]
# ### *Correlograms*
