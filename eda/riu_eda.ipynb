# %% [markdown]
# ## Webpage Phishing Detection EDA - Riu
# ### *Columns 46 - 67*

# %%
#Import Modules
import pandas as pd
import numpy as np

# %%
#Read data
df = pd.read_csv("../data/dataset_phishing.csv")

# %%
#Subset data (columns 46 - 67 and label)
df = df.iloc[:, np.r_[45:67, 88]]

# %%
#Display sample
df.sample(10, random_state = 373)
# Out:
#        longest_words_raw  longest_word_host  longest_word_path  avg_words_raw  \
# 6309                  17                 14                 17       7.538462
# 3116                  13                 13                  9       8.333333
# 8307                  10                  9                 10       6.833333
# 8309                   9                  9                  8       6.200000
# 2807                  40                 10                 40       9.894737
# 7693                  12                 12                  9       7.000000
# 1090                   9                  9                  8       5.800000
# 9597                  13                 13                  8       4.533333
# 9546                  12                 12                 10       6.666667
# 11195                 10                 10                  0       6.500000
#
#        avg_word_host  avg_word_path  phish_hints  domain_in_brand  \
# 6309            14.0       6.363636            0                0
# 3116             8.0       9.000000            0                0
# 8307             5.5       7.500000            0                1
# 8309             5.5       6.666667            0                1
# 2807            10.0       9.888889            3                0
# 7693            12.0       5.750000            1                0
# 1090             6.0       5.666667            0                0
# 9597             9.5       3.769231            0                0
# 9546             7.5       6.538462            0                0
# 11195            6.5       0.000000            0                0
#
#        brand_in_subdomain  brand_in_path  ...  ratio_intHyperlinks  \
# 6309                    0              0  ...             0.930693
# 3116                    0              0  ...             0.666667
# 8307                    0              0  ...             0.949686
# 8309                    0              0  ...             0.937278
# 2807                    0              0  ...             0.863636
# 7693                    0              0  ...             0.941935
# 1090                    0              0  ...             0.793427
# 9597                    0              0  ...             0.000000
# 9546                    0              0  ...             0.948905
# 11195                   0              0  ...             0.779661
#
#        ratio_extHyperlinks  ratio_nullHyperlinks  nb_extCSS  \
# 6309              0.069307                     0          0
# 3116              0.333333                     0          0
# 8307              0.050314                     0          0
# 8309              0.062722                     0          0
# 2807              0.136364                     0          1
# 7693              0.058065                     0          0
# 1090              0.206573                     0          2
# 9597              0.000000                     0          0
# 9546              0.051095                     0          0
# 11195             0.220339                     0          0
#
#        ratio_intRedirection  ratio_extRedirection  ratio_intErrors  \
# 6309                      0              0.571429                0
# 3116                      0              0.000000                0
# 8307                      0              0.375000                0
# 8309                      0              0.245283                0
# 2807                      0              0.000000                0
# 7693                      0              0.444444                0
# 1090                      0              0.386364                0
# 9597                      0              0.000000                0
# 9546                      0              0.857143                0
# 11195                     0              0.038462                0
#
#        ratio_extErrors  login_form      status
# 6309          0.000000           0  legitimate
# 3116          0.000000           0  legitimate
# 8307          0.000000           0  legitimate
# 8309          0.075472           0  legitimate
# 2807          0.000000           0    phishing
# 7693          0.222222           0    phishing
# 1090          0.000000           0  legitimate
# 9597          0.000000           0  legitimate
# 9546          0.285714           0  legitimate
# 11195         0.038462           0  legitimate
#
# [10 rows x 23 columns]

# %%
#Display shape
df.shape
# Out:
# (11430, 23)

# %%
#Column data types
df.dtypes
# Out:
# longest_words_raw         int64
# longest_word_host         int64
# longest_word_path         int64
# avg_words_raw           float64
# avg_word_host           float64
# avg_word_path           float64
# phish_hints               int64
# domain_in_brand           int64
# brand_in_subdomain        int64
# brand_in_path             int64
# suspecious_tld            int64
# statistical_report        int64
# nb_hyperlinks             int64
# ratio_intHyperlinks     float64
# ratio_extHyperlinks     float64
# ratio_nullHyperlinks      int64
# nb_extCSS                 int64
# ratio_intRedirection      int64
# ratio_extRedirection    float64
# ratio_intErrors           int64
# ratio_extErrors         float64
# login_form                int64
# status                   object
# dtype: object

# %%
#Check for potentially missing values
df.isna().sum()
# Out:
# longest_words_raw       0
# longest_word_host       0
# longest_word_path       0
# avg_words_raw           0
# avg_word_host           0
# avg_word_path           0
# phish_hints             0
# domain_in_brand         0
# brand_in_subdomain      0
# brand_in_path           0
# suspecious_tld          0
# statistical_report      0
# nb_hyperlinks           0
# ratio_intHyperlinks     0
# ratio_extHyperlinks     0
# ratio_nullHyperlinks    0
# nb_extCSS               0
# ratio_intRedirection    0
# ratio_extRedirection    0
# ratio_intErrors         0
# ratio_extErrors         0
# login_form              0
# status                  0
# dtype: int64

# %% [markdown]
# ### *Distribution of Each Feature*
